# %%
import subprocess, sys

# Install to the exact Python the notebook is using
subprocess.run([sys.executable, "-m", "pip", "install", "hd-bet==1.1", "-q"], check=True)

# Verify it's importable
try:
    from HD_BET.run import run_hd_bet
    print("HD-BET import successful")
except ImportError as e:
    print("Still failing:", e)
    # Show where Python is looking
    import site
    print("Site packages:", site.getsitepackages())
# Out:
# HD-BET import successful

# %%
import warnings
import subprocess
from google.colab import drive

warnings.filterwarnings('ignore')
drive.mount('/content/drive')

# Install dependencies
# !pip install "hd-bet==1.1" antspyx neuroCombat nibabel numpy Pillow tqdm pandas --ignore-installed argparse

# Run the pipeline
# !python /content/drive/MyDrive/schizophrenia_gan/scripts/preprocess.py \
  --ucla_dir    /content/drive/MyDrive/schizophrenia_gan/data/raw/ucla_cnp \
  --cobre_dir   /content/drive/MyDrive/schizophrenia_gan/data/raw/cobre \
  --out_dir     /content/drive/MyDrive/schizophrenia_gan/data/preprocessed \
  --slices_dir  /content/drive/MyDrive/schizophrenia_gan/data/slices # \
  # --test_run
# Out:
# Mounted at /content/drive
# ...
#   Using cached hd_bet-1.1-py3-none-any.whl
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.7/57.7 kB 2.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 5.9 MB/s eta 0:00:00
# ...
#   Using cached simpleitk-2.5.4-cp311-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (7.4 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 kB 3.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 kB 3.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 3.5 MB/s eta 0:00:00
# ...
#   Using cached packaging-26.2-py3-none-any.whl.metadata (3.5 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.5/117.5 kB 7.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.9/40.9 kB 2.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.4/22.4 MB 43.2 MB/s eta 0:00:00
# ...

# %%
import warnings
import subprocess
from google.colab import drive

warnings.filterwarnings('ignore')
drive.mount('/content/drive')

# !pip install neuroCombat nibabel numpy Pillow tqdm pandas -q

# !python /content/drive/MyDrive/schizophrenia_gan/scripts/make_slices.py \
  --preprocessed_dir /content/drive/MyDrive/schizophrenia_gan/data/preprocessed \
  --slices_dir       /content/drive/MyDrive/schizophrenia_gan/data/slices
# Out:
# Mounted at /content/drive
#   Preparing metadata (setup.py) ... done
#   Building wheel for neuroCombat (setup.py) ... done
# 2026-05-09 09:37:21,401 [INFO] Found 139 completed subjects out of 274 total
# 2026-05-09 09:37:21,402 [INFO]   SCZ: 13
# 2026-05-09 09:37:21,402 [INFO]   HC:  126
# 2026-05-09 09:37:21,402 [INFO]   Skipped (not yet preprocessed): 135
# 2026-05-09 09:37:21,403 [INFO]   Sites: {'UCLA': 137, 'COBRE': 2}
# 2026-05-09 09:37:21,403 [INFO] Running ComBat harmonization...
# 2026-05-09 09:37:21,404 [INFO] Loading volumes for ComBat harmonization...
# Loading: 100% 139/139 [02:59<00:00,  1.29s/it]
# 2026-05-09 09:40:22,704 [INFO] Running ComBat on 139 subjects across 2 sites: ['COBRE' 'UCLA']
# [neuroCombat] Creating design matrix
# [neuroCombat] Standardizing data across features
# [neuroCombat] Fitting L/S model and finding priors
# [neuroCombat] Finding parametric adjustments
# /usr/local/lib/python3.12/dist-packages/neuroCombat/neuroCombat.py:324: RuntimeWarning: divide by zero encountered in divide
#   change = max((abs(g_new - g_old) / g_old).max(), (abs(d_new - d_old) / d_old).max())
# [neuroCombat] Final adjustment of data
# /content/drive/MyDrive/schizophrenia_gan/scripts/make_slices.py:164: RuntimeWarning: divide by zero encountered in divide
#   ratio        = np.where(orig_means != 0, combat_means / orig_means, 1.0)
# 2026-05-09 09:40:40,628 [INFO] ComBat harmonization complete.
# 2026-05-09 09:40:40,630 [INFO] Normalizing and extracting slices...
# Slicing:  27% 37/139 [16:05<42:36, 25.06s/it]

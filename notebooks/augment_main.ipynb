# %%
import warnings
import subprocess
from google.colab import drive

warnings.filterwarnings('ignore')
drive.mount('/content/drive')

# Install dependencies
# !pip install "hd-bet==1.1" antspyx neuroCombat nibabel numpy Pillow tqdm pandas torch torchvision --ignore-installed argparse
# Out:
# Mounted at /content/drive
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.7/57.7 kB 3.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 5.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 kB 4.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 kB 3.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 3.9 MB/s eta 0:00:00
# ...
#   Using cached packaging-26.2-py3-none-any.whl.metadata (3.5 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.5/117.5 kB 7.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.9/40.9 kB 1.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.4/22.4 MB 48.9 MB/s eta 0:00:00
# ...

# %%
# Traditional augment
# !python /content/drive/MyDrive/schizophrenia_gan/scripts/augment.py --mode traditional
# Out:
# Using device: cpu
# Running traditional augmentation only...
# [Traditional] Augmented 8820 images → /content/drive/MyDrive/schizophrenia_gan/data/augmented/traditional/healthy
# [Traditional] Augmented 910 images → /content/drive/MyDrive/schizophrenia_gan/data/augmented/traditional/schizophrenia

# %%
# Conditional DCGAN
# !python /content/drive/MyDrive/schizophrenia_gan/scripts/augment.py --mode dcgan --epochs 50
# Out:
# Using device: cuda
# Running DCGAN only...
# [DCGAN] Training from scratch...
# [DCGAN] Epoch [1/50]  loss_G=4.7593  loss_D=0.3234
# [DCGAN] Epoch [2/50]  loss_G=1.5568  loss_D=0.5396
# [DCGAN] Epoch [3/50]  loss_G=5.3559  loss_D=0.6409
# [DCGAN] Epoch [4/50]  loss_G=4.7252  loss_D=0.7209
# [DCGAN] Epoch [5/50]  loss_G=2.7940  loss_D=0.1172
# [DCGAN] Epoch [6/50]  loss_G=4.8970  loss_D=0.1728
# [DCGAN] Epoch [7/50]  loss_G=10.4758  loss_D=0.4317
# [DCGAN] Epoch [8/50]  loss_G=5.4227  loss_D=0.3588
# [DCGAN] Epoch [9/50]  loss_G=3.0097  loss_D=0.5644
# [DCGAN] Epoch [10/50]  loss_G=4.6136  loss_D=0.2294
# [DCGAN] Epoch [11/50]  loss_G=5.8987  loss_D=0.0842
# [DCGAN] Epoch [12/50]  loss_G=5.4080  loss_D=0.6370
# [DCGAN] Epoch [13/50]  loss_G=2.3753  loss_D=0.5870
# [DCGAN] Epoch [14/50]  loss_G=13.4740  loss_D=1.3155
# [DCGAN] Epoch [15/50]  loss_G=6.7162  loss_D=0.6216
# [DCGAN] Epoch [16/50]  loss_G=4.4137  loss_D=0.2269
# [DCGAN] Epoch [17/50]  loss_G=3.9844  loss_D=0.4439
# ...

# %%
# Conditional patchgan
# !python3 /content/drive/MyDrive/schizophrenia_gan/scripts/augment.py --mode patchgan --epochs 50
# Out:
# Using device: cuda
# Running PatchGAN only...
# [PatchGAN] Training from scratch...
# [PatchGAN] Epoch [1/50]  loss_G=0.7823  loss_D=0.1471
# [PatchGAN] Epoch [2/50]  loss_G=1.0305  loss_D=0.0861
# [PatchGAN] Epoch [3/50]  loss_G=1.2355  loss_D=0.0374
# [PatchGAN] Epoch [4/50]  loss_G=1.1360  loss_D=0.0672
# [PatchGAN] Epoch [5/50]  loss_G=0.9255  loss_D=0.0955
# [PatchGAN] Epoch [6/50]  loss_G=1.0503  loss_D=0.0632
# [PatchGAN] Epoch [7/50]  loss_G=1.0329  loss_D=0.1318
# [PatchGAN] Epoch [8/50]  loss_G=0.5490  loss_D=0.1759
# [PatchGAN] Epoch [9/50]  loss_G=0.9046  loss_D=0.1220
# [PatchGAN] Epoch [10/50]  loss_G=0.9024  loss_D=0.1608
# [PatchGAN] Epoch [11/50]  loss_G=0.4680  loss_D=0.2058
# [PatchGAN] Epoch [12/50]  loss_G=0.8852  loss_D=0.1189
# [PatchGAN] Epoch [13/50]  loss_G=0.6445  loss_D=0.2007
# [PatchGAN] Epoch [14/50]  loss_G=0.6878  loss_D=0.1570
# [PatchGAN] Epoch [15/50]  loss_G=0.8036  loss_D=0.1809
# [PatchGAN] Epoch [16/50]  loss_G=0.7526  loss_D=0.1404
# ...
